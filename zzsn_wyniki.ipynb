# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
results = pd.read_csv("testing_results_min.txt", sep=",", names=["model", "n_way_test", "n_shot_test", "n_quert_test", "dist", "n_test_episodes", "accuracy"])

# %%
results.columns
# Out:
# Index(['model', 'n_way_test', 'n_shot_test', 'n_quert_test', 'dist',
#        'n_test_episodes', 'accuracy'],
#       dtype='object')

# %%
results["n_way"] = [int(model[model.find("w")+1:model.find("s")]) for model in results["model"]]
results["n_shot"] = [int(model[model.find("s")+1:model.find("q")]) for model in results["model"]]
results["n_query"] = [int(model[model.find("q")+1:model.find("e")]) for model in results["model"]]
results["n_episodes"] = [int(model[model.find("e")+1:model.find("e")+3]) for model in results["model"]]

# %%
results
# Out:
#                 model  n_way_test  n_shot_test  n_quert_test       dist  \
# 0   MINw30s1q15e10cos           5            1            15     cosine
# 1   MINw30s1q15e10cos           5            5            15     cosine
# 2   MINw30s1q15e10euc           5            1            15  euclidean
# 3   MINw30s1q15e10euc           5            5            15  euclidean
# 4   MINw20s1q15e10cos           5            1            15     cosine
# 5   MINw20s1q15e10cos           5            5            15     cosine
# 6    MINw5s1q15e10cos           5            1            15     cosine
# 7    MINw5s1q15e10cos           5            5            15     cosine
# 8   MINw20s1q15e10euc           5            1            15  euclidean
# 9   MINw20s1q15e10euc           5            5            15  euclidean
# 10   MINw5s1q15e10euc           5            1            15  euclidean
# 11   MINw5s1q15e10euc           5            5            15  euclidean
# ...

# %%
m1[m1.find("w")+1:m1.find("s")]
# Out:
# '30'

# %%
results_omn = pd.read_csv("testing_results_omn.txt", sep=",", names=["model", "n_way_test", "n_shot_test", "n_quert_test", "dist", "n_test_episodes", "accuracy"])

# %%
results_omn.columns
# Out:
# Index(['model', 'n_way_test', 'n_shot_test', 'n_quert_test', 'dist',
#        'n_test_episodes', 'accuracy'],
#       dtype='object')

# %%
results_omn["n_way"] = [int(model[model.find("w")+1:model.find("s")]) for model in results["model"]]
results_omn["n_shot"] = [int(model[model.find("s")+1:model.find("q")]) for model in results["model"]]
results_omn["n_query"] = [int(model[model.find("q")+1:model.find("e")]) for model in results["model"]]
results_omn["n_episodes"] = [int(model[model.find("e")+1:model.find("e")+3]) for model in results["model"]]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 results_omn["n_way"] = [int(model[model.find("w")+1:model.find("s")]) for model in results["model"]]
#       2 results_omn["n_shot"] = [int(model[model.find("s")+1:model.find("q")]) for model in results["model"]]
#       3 results_omn["n_query"] = [int(model[model.find("q")+1:model.find("e")]) for model in results["model"]]
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/frame.py:3978, in DataFrame.__setitem__(self, key, value)
#    3975     self._setitem_array([key], value)
#    3976 else:
#    3977     # set column
# -> 3978     self._set_item(key, value)
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/frame.py:4172, in DataFrame._set_item(self, key, value)
#    4162 def _set_item(self, key, value) -> None:
#    4163     """
# ...

# %%
results_omn
# Out:
#                model  n_way_test  n_shot_test  n_quert_test       dist  \
# 0  OMNw60s1q5e100cos           5            1            15     cosine
# 1  OMNw60s1q5e100cos           5            5            15     cosine
# 2  OMNw60s5q5e100cos           5            1            15     cosine
# 3  OMNw60s5q5e100cos           5            5            15     cosine
# 4  OMNw60s1q5e100euc           5            1            15  euclidean
# 5  OMNw60s1q5e100euc           5            5            15  euclidean
# 6  OMNw60s5q5e100euc           5            1            15  euclidean
# 7  OMNw60s5q5e100euc           5            5            15  euclidean
#
#    n_test_episodes  accuracy
# 0             1000  0.953520
# 1             1000  0.988973
# 2             1000  0.949320
# 3             1000  0.988920
# 4             1000  0.947360
# 5             1000  0.986973
# 6             1000  0.947133
# 7             1000  0.989280
